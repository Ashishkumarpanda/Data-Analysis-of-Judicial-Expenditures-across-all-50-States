# %%
from google.colab import files
a= files.upload()
# Out:
#      <input type="file" id="files-a802f5d6-0fa7-4453-9a3f-0cb53f6ab79e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a802f5d6-0fa7-4453-9a3f-0cb53f6ab79e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data (1).csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("Data.csv")
data['State'] = LabelEncoder().fit_transform(data['State'])
data.head(10)
# Out:
#    State  ...  Corrections Employment
# 0     44  ...                    21.78
# 1      0  ...                    16.62
# 2      1  ...                    31.42
# 3      2  ...                    21.85
# 4      3  ...                    27.41
# 5      4  ...                    22.89
# 6      5  ...                    20.60
# 7      6  ...                    16.20
# 8      7  ...                    30.87
# 9      8  ...                    19.78
#
# [10 rows x 11 columns]

# %%
data.describe()
# Out:
#            State  ...  Corrections Employment
# count  52.000000  ...                52.000000
# mean   25.500000  ...                21.091154
# std    15.154757  ...                 4.866900
# min     0.000000  ...                13.600000
# 25%    12.750000  ...                17.645000
# 50%    25.500000  ...                20.095000
# 75%    38.250000  ...                24.497500
# max    51.000000  ...                33.340000
#
# [8 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# State                                       0
# Population 2016                             0
# Total justice system PC                     0
# Police Protection PC                        0
# Judicial and legal PC                       0
# Corrections PC                              0
# Total justice system Employment             0
# police protection Total Employment          0
# police protection Sworn only Employment     0
# Judicial and legal Employment               0
# Corrections Employment                      0
# dtype: int64

# %%
for i in data.columns:
  print(i)
# Out:
# State
# Population 2016
# Total justice system PC
# Police Protection PC
# Judicial and legal PC
# Corrections PC
# Total justice system Employment
# police protection Total Employment
# police protection Sworn only Employment
# Judicial and legal Employment
# Corrections Employment

# %%
sns.heatmap(data.isnull())

# %%
plt.subplot(2,1,1)
sns.distplot(data['State'],bins=10,color='g')
plt.subplot(2,1,2)
sns.distplot(data['Population 2016'])
plt.style.use("dark_background")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.subplot(2,1,1)
sns.distplot(data['Corrections Employment '],bins=10,color='g')
plt.subplot(2,1,2)
sns.distplot(data['Corrections PC'],bins=10)

plt.style.use("dark_background")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.subplot(2,1,1)
sns.distplot(data['Judicial and legal Employment '],bins=10,color='g')
plt.subplot(2,1,2)
sns.distplot(data['Judicial and legal PC'],bins=10)

plt.style.use("dark_background")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.subplot(2,1,1)
sns.distplot(data['Police Protection PC'],bins=10,color='g')
plt.subplot(2,1,2)
sns.distplot(data['police protection Sworn only Employment '],bins=10)

plt.style.use("dark_background")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.subplot(3,1,1)
sns.distplot(data['police protection Total Employment '],bins=10,color='g')
plt.subplot(3,1,2)
sns.distplot(data['Total justice system Employment '],bins=10)
plt.subplot(3,1,3)
sns.distplot(data['Total justice system PC '],bins=10,color='r')

plt.style.use("dark_background")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.scatter(data['Police Protection PC'],data['police protection Sworn only Employment '])

# %%
plt.pie(data['Total justice system Employment '])
plt.legend()
# Out:
# No handles with labels found to put in legend.
